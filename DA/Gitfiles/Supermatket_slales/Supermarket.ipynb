# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
ss_df= pd.read_csv('supermarket_sales.csv')

# %%
ss_df
# Out:
#       invoice_id branch       city customer_type gender_customer  \
# 0    750-67-8428      A     Yangon        Member          Female
# 1    226-31-3081      C  Naypyitaw        Normal          Female
# 2    631-41-3108      A     Yangon        Normal            Male
# 3    123-19-1176      A     Yangon        Member            Male
# 4    373-73-7910      A     Yangon        Normal            Male
# ..           ...    ...        ...           ...             ...
# 995  233-67-5758      C  Naypyitaw        Normal            Male
# 996  303-96-2227      B   Mandalay        Normal          Female
# 997  727-02-1313      A     Yangon        Member            Male
# 998  347-56-2442      A     Yangon        Normal            Male
# 999  849-09-3807      A     Yangon        Member          Female
#
#                product_line  unit_cost  quantity  5pct_markup    revenue  \
# 0         Health and beauty      74.69         7      26.1415   548.9715
# ...

# %%
ss_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice_id       1000 non-null   object
#  1   branch           1000 non-null   object
#  2   city             1000 non-null   object
#  3   customer_type    1000 non-null   object
#  4   gender_customer  1000 non-null   object
#  5   product_line     1000 non-null   object
#  6   unit_cost        1000 non-null   float64
#  7   quantity         1000 non-null   int64
#  8   5pct_markup      1000 non-null   float64
#  9   revenue          1000 non-null   float64
#  10  date             1000 non-null   object
#  11  time             1000 non-null   object
#  12  payment_method   1000 non-null   object
#  13  cogs             1000 non-null   float64
#  14  gm_pct           1000 non-null   float64
#  15  gross_income     1000 non-null   float64
# ...

# %%
ss_df.isna()
# Out:
#      invoice_id  branch   city  customer_type  gender_customer  product_line  \
# 0         False   False  False          False            False         False
# 1         False   False  False          False            False         False
# 2         False   False  False          False            False         False
# 3         False   False  False          False            False         False
# 4         False   False  False          False            False         False
# ..          ...     ...    ...            ...              ...           ...
# 995       False   False  False          False            False         False
# 996       False   False  False          False            False         False
# 997       False   False  False          False            False         False
# 998       False   False  False          False            False         False
# 999       False   False  False          False            False         False
#
# ...

# %%
ss_df.isna().sum()
# Out:
# invoice_id         0
# branch             0
# city               0
# customer_type      0
# gender_customer    0
# product_line       0
# unit_cost          0
# quantity           0
# 5pct_markup        0
# revenue            0
# date               0
# time               0
# payment_method     0
# cogs               0
# gm_pct             0
# gross_income       0
# rating             0
# dtype: int64

# %%
ss_df.isna().sum().sum()
# Out:
# 0

# %%
ss_df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'customer_type', 'gender_customer',
#        'product_line', 'unit_cost', 'quantity', '5pct_markup', 'revenue',
#        'date', 'time', 'payment_method', 'cogs', 'gm_pct', 'gross_income',
#        'rating'],
#       dtype='object')

# %%
ss_df.head()
# Out:
#     invoice_id branch       city customer_type gender_customer  \
# 0  750-67-8428      A     Yangon        Member          Female
# 1  226-31-3081      C  Naypyitaw        Normal          Female
# 2  631-41-3108      A     Yangon        Normal            Male
# 3  123-19-1176      A     Yangon        Member            Male
# 4  373-73-7910      A     Yangon        Normal            Male
#
#              product_line  unit_cost  quantity  5pct_markup   revenue  \
# 0       Health and beauty      74.69         7      26.1415  548.9715
# 1  Electronic accessories      15.28         5       3.8200   80.2200
# 2      Home and lifestyle      46.33         7      16.2155  340.5255
# 3       Health and beauty      58.22         8      23.2880  489.0480
# 4       Sports and travel      86.31         7      30.2085  634.3785
#
#         date   time payment_method    cogs    gm_pct  gross_income  rating
# 0   01/05/19  13:08        Ewallet  522.83  4.761905       26.1415     9.1
# ...

# %%
ss_df.describe(include='all').T
# Out:
#                   count unique                  top freq        mean  \
# invoice_id         1000   1000          750-67-8428    1         NaN
# branch             1000      3                    A  340         NaN
# city               1000      3               Yangon  340         NaN
# customer_type      1000      2               Member  501         NaN
# gender_customer    1000      2               Female  501         NaN
# product_line       1000      6  Fashion accessories  178         NaN
# unit_cost        1000.0    NaN                  NaN  NaN    55.67213
# quantity         1000.0    NaN                  NaN  NaN        5.51
# 5pct_markup      1000.0    NaN                  NaN  NaN   15.379369
# revenue          1000.0    NaN                  NaN  NaN  322.966749
# date               1000     89             02/07/19   20         NaN
# time               1000    506                19:48    7         NaN
# payment_method     1000      3              Ewallet  345         NaN
# ...

# %%
sm_df= ss_df.copy()

# %%
sm_df
# Out:
#       invoice_id branch       city customer_type gender_customer  \
# 0    750-67-8428      A     Yangon        Member          Female
# 1    226-31-3081      C  Naypyitaw        Normal          Female
# 2    631-41-3108      A     Yangon        Normal            Male
# 3    123-19-1176      A     Yangon        Member            Male
# 4    373-73-7910      A     Yangon        Normal            Male
# ..           ...    ...        ...           ...             ...
# 995  233-67-5758      C  Naypyitaw        Normal            Male
# 996  303-96-2227      B   Mandalay        Normal          Female
# 997  727-02-1313      A     Yangon        Member            Male
# 998  347-56-2442      A     Yangon        Normal            Male
# 999  849-09-3807      A     Yangon        Member          Female
#
#                product_line  unit_cost  quantity  5pct_markup    revenue  \
# 0         Health and beauty      74.69         7      26.1415   548.9715
# ...

# %%
sm_df.city.unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
sm_df.product_line.unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
sm_df.city.value_counts()
# Out:
# city
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
sm_df.product_line.value_counts()
# Out:
# product_line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
cr= sm_df.groupby('city').sum('revenue')

# %%
cr
# Out:
#            unit_cost  quantity  5pct_markup      revenue       cogs  \
# city
# Mandalay    18478.88      1820    5057.0320  106197.6720  101140.64
# Naypyitaw   18567.76      1831    5265.1765  110568.7065  105303.53
# Yangon      18625.49      1859    5057.1605  106200.3705  101143.21
#
#                 gm_pct  gross_income  rating
# city
# Mandalay   1580.952381     5057.0320  2263.6
# Naypyitaw  1561.904762     5265.1765  2319.9
# Yangon     1619.047619     5057.1605  2389.2

# %%
cr.revenue
# Out:
# city
# Mandalay     106197.6720
# Naypyitaw    110568.7065
# Yangon       106200.3705
# Name: revenue, dtype: float64

# %%
cr.quantity
# Out:
# city
# Mandalay     1820
# Naypyitaw    1831
# Yangon       1859
# Name: quantity, dtype: int64

# %%
cp= sm_df.groupby('product_line').sum('revenue')

# %%
cp
# Out:
#                         unit_cost  quantity  5pct_markup     revenue  \
# product_line
# Electronic accessories    9103.77       971    2587.5015  54337.5315
# Fashion accessories      10173.35       902    2585.9950  54305.8950
# Food and beverages        9745.54       952    2673.5640  56144.8440
# Health and beauty         8337.88       854    2342.5590  49193.7390
# Home and lifestyle        8850.71       911    2564.8530  53861.9130
# Sports and travel         9460.88       920    2624.8965  55122.8265
#
#                             cogs      gm_pct  gross_income  rating
# product_line
# Electronic accessories  51750.03  809.523810     2587.5015  1177.2
# Fashion accessories     51719.90  847.619048     2585.9950  1251.2
# Food and beverages      53471.28  828.571429     2673.5640  1237.7
# Health and beauty       46851.18  723.809524     2342.5590  1064.5
# Home and lifestyle      51297.06  761.904762     2564.8530  1094.0
# ...

# %%
cp.quantity
# Out:
# product_line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: quantity, dtype: int64

# %%
cp.revenue
# Out:
# product_line
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Food and beverages        56144.8440
# Health and beauty         49193.7390
# Home and lifestyle        53861.9130
# Sports and travel         55122.8265
# Name: revenue, dtype: float64

# %%
pr= sm_df.groupby('product_line').mean('rating')

# %%
pr
# Out:
#                         unit_cost  quantity  5pct_markup     revenue  \
# product_line
# Electronic accessories  53.551588  5.711765    15.220597  319.632538
# Fashion accessories     57.153652  5.067416    14.528062  305.089298
# Food and beverages      56.008851  5.471264    15.365310  322.671517
# Health and beauty       54.854474  5.618421    15.411572  323.643020
# Home and lifestyle      55.316937  5.693750    16.030331  336.636956
# Sports and travel       56.993253  5.542169    15.812630  332.065220
#
#                               cogs    gm_pct  gross_income    rating
# product_line
# Electronic accessories  304.411941  4.761905     15.220597  6.924706
# Fashion accessories     290.561236  4.761905     14.528062  7.029213
# Food and beverages      307.306207  4.761905     15.365310  7.113218
# Health and beauty       308.231447  4.761905     15.411572  7.003289
# Home and lifestyle      320.606625  4.761905     16.030331  6.837500
# ...

# %%
pr.rating
# Out:
# product_line
# Electronic accessories    6.924706
# Fashion accessories       7.029213
# Food and beverages        7.113218
# Health and beauty         7.003289
# Home and lifestyle        6.837500
# Sports and travel         6.916265
# Name: rating, dtype: float64

# %%
plt.figure()
#plt.style.use('ggplot')
group_by_city=pd.Grouper(key="city")
revenue_by_city=sm_df.groupby(group_by_city)["revenue"].sum()
colors = ['#FAC500', '#FADF6B', '#FBEBA9']
plt.bar(revenue_by_city.index, revenue_by_city, color=colors, width=0.3)
plt.xlabel("City")
plt.ylabel("Revenue")
plt.title("Revenue generated per city")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(13, 7))
group_by_product=pd.Grouper(key="product_line")
revunue_by_productline=sm_df.groupby(group_by_product)["revenue"].sum()
col=("#FCA182","#FCD982","#EBFC82","#89FC82","#82FCD9","#82DBFC","#8289FC")
plt.bar(revunue_by_productline.index, revunue_by_productline, color=col, width=0.5)
plt.xlabel("Product line")
plt.ylabel("Revenue")
plt.title("Revenue generated per product")
plt.show()

# %%
sm_df.date
# Out:
# 0       01/05/19
# 1       03/08/19
# 2       03/03/19
# 3      1/27/2019
# 4       02/08/19
#          ...
# 995    1/29/2019
# 996     03/02/19
# 997     02/09/19
# 998    2/22/2019
# 999    2/18/2019
# Name: date, Length: 1000, dtype: object

# %%
sm_df['date']=pd.to_datetime(sm_df['date'])
sm_df['month']=sm_df['date'].dt.month
sm_df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'customer_type', 'gender_customer',
#        'product_line', 'unit_cost', 'quantity', '5pct_markup', 'revenue',
#        'date', 'time', 'payment_method', 'cogs', 'gm_pct', 'gross_income',
#        'rating', 'month'],
#       dtype='object')

# %%
sm_df[['month','date']]
# Out:
#      month       date
# 0        1 2019-01-05
# 1        3 2019-03-08
# 2        3 2019-03-03
# 3        1 2019-01-27
# 4        2 2019-02-08
# ..     ...        ...
# 995      1 2019-01-29
# 996      3 2019-03-02
# 997      2 2019-02-09
# 998      2 2019-02-22
# 999      2 2019-02-18
#
# [1000 rows x 2 columns]

# %%
sm_df.month
# Out:
# 0      1
# 1      3
# 2      3
# 3      1
# 4      2
#       ..
# 995    1
# 996    3
# 997    2
# 998    2
# 999    2
# Name: month, Length: 1000, dtype: int32

# %%
#sm_df['date']=pd.to_datetime(sm_df['date'])
#monthly_data = sm_df.set_index('date').resample('M').sum()
#monthly_data.revenue
# Out:
# date
# 2019-01-31    116291.868
# 2019-02-28     97219.374
# 2019-03-31    109455.507
# Freq: M, Name: revenue, dtype: float64

# %%
plt.figure(figsize=(5, 6))
month_data=pd.Grouper(key='month')
monthly_revenue=sm_df.groupby(month_data)["revenue"].sum()
plt.bar(monthly_revenue.index, monthly_revenue, color=col, width=0.3)
plt.xlabel('Month')
plt.ylabel("Revenue")
plt.title("Revenue generated per month")
plt.plot()
# Out:
# []
